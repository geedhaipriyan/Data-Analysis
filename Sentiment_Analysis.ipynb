# %% [markdown]
# <a href="https://colab.research.google.com/github/geedhaipriyan/Hello-world-/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2019.3.9)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 3.8MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'mGe0qQBT9KRk7gLNv2rWx069N'
consumer_secret = 'CRfeF7TPCJlo5Vj9d97BDo4c1ErI5ggWmMnrWYtD8eybCfEv1E'
access_token = '1430929286-sA4yTd5C2ST2BeQyY1rMcGlSBpTjkwU6BsT5cPo'
access_token_secret = 'BnrOkIQVtJXy1I9dU6tLqRWDjpp4nlfgDhUic6ovBGhbh'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('scadia', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  #GTLive explaining Google's Scadia (which is b...
# 1  @Gillstolemyride @zDamascus @fgc_kanoran What ...
# 2  Recruiters in 3 years\n\nMinimum requirement: ...
# 3  So excited for Google Scadia. I hope it's easi...
# 4  @Silberdamian A ver Damián, cuanto crees le qu...
# 5  @RippyRizza Rippy, como crees que le pega Scad...
# 6  ¡Te recomiendo que escuches este audio de iVoo...
# 7  mobile gaming has ushered in pay to play model...
# 8  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 9  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 2019-03-23 06:40:59

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   #GTLive explaining Google's Scadia (which is b...
# 1   @Gillstolemyride @zDamascus @fgc_kanoran What ...
# 2   Recruiters in 3 years\n\nMinimum requirement: ...
# 3   So excited for Google Scadia. I hope it's easi...
# 4   @Silberdamian A ver Damián, cuanto crees le qu...
# 5   @RippyRizza Rippy, como crees que le pega Scad...
# 6   ¡Te recomiendo que escuches este audio de iVoo...
# 7   mobile gaming has ushered in pay to play model...
# 8   RT @dendiriandi: Google Scadia.\nMain game dgn...
# 9   RT @dendiriandi: Google Scadia.\nMain game dgn...
# 10  RT @DisketDance: ATENÇÃO\nPara usar o Google S...
# 11  @NicoNiiNiconite @yoshi45111 this is why you d...
# 12                    E essa Scadia?? gente q loucura
# 13  A new metric is created: #SISPSS for #Scadia #...
# 14  Google will track you through their gazillion ...
# 15  Google enters onine gaming with Scadia - Game ...
# 16  RT @DisketDance: ATENÇÃO\nPara usar o Google S...
# 17  RT @canoncosmo: He publicado un episodio en #i...
# 18  He publicado un episodio en #ivoox "1x18: No l...
# 19  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 20  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 21  RT @DisketDance: ATENÇÃO\nPara usar o Google S...
# 22  scadia is cute, but it doesn't look secure to ...
# 23  @Buster_Boy22 @IGN So Scadia will just be upgr...
# 24  RT @mikel_pernia: @prioratodexion @Palomeski M...
# 25  Imagine Google's new Scadia gaming product -wh...
# 26  RT @DisketDance: ATENÇÃO\nPara usar o Google S...
# 27  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 28  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 29  RT @dendiriandi: Google Scadia.\nMain game dgn...
# 30  Google Scadia.\nMain game dgn grafis bagus sec...
# 31  RT @DisketDance: ATENÇÃO\nPara usar o Google S...
# 32   Google Scabia or Scadia or whatever is gon flop.
# 33  ATENÇÃO\nPara usar o Google Scadia você vai pr...
# 34  @prioratodexion @Palomeski Microsoft se monta ...
# 35                    não faz nem sentido esse Scadia
# 36  The Google Scadia? Arcadia? Stadia? I think it...
# 37                     Scadia es como una Super Xbox.
# 38  Je dois être nostalgique, mais voir la  #Googl...
# 39  @KhrisKii I ain’t got time to be sittin round ...
# 40  Então o Google vai investir pesado em games no...
# 41  “Scadia is not limited by the constraints of m...
# 42  @Google Scadia demo, you can see the input lag...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'comp...
# 7   {'neg': 0.067, 'neu': 0.817, 'pos': 0.115, 'co...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.058, 'neu': 0.942, 'pos': 0.0, 'comp...
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13  {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'comp...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'comp...
# 18  {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'comp...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22  {'neg': 0.384, 'neu': 0.555, 'pos': 0.062, 'co...
# 23  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'comp...
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25  {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'comp...
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 32  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 36  {'neg': 0.175, 'neu': 0.825, 'pos': 0.0, 'comp...
# 37  {'neg': 0.0, 'neu': 0.562, 'pos': 0.438, 'comp...
# 38  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 39  {'neg': 0.24, 'neu': 0.661, 'pos': 0.099, 'com...
# 40  {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'comp...
# 41  {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'comp...
# 42  {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'comp...
